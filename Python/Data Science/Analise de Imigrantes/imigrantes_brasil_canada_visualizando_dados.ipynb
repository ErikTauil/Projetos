# %%
import pandas as pd
df = pd.read_csv ("C:\\Users\\RedSeek\\Desktop\\DATA SCIENCE FORMACAO\\Imigrantes do Brasil para o Canada\\imigrantes_canada.csv")
df
# Out:
#                 País Continente            Região  1980  1981  1982  1983  \
# 0        Afeganistão       Ásia       Sul da Ásia    16    39    39    47
# 1            Albânia     Europa     Sul da Europa     1     0     0     0
# 2            Argélia     África   Norte da África    80    67    71    69
# 3    Samoa Americana    Oceânia         Polinésia     0     1     0     0
# 4            Andorra     Europa     Sul da Europa     0     0     0     0
# ..               ...        ...               ...   ...   ...   ...   ...
# 190           Vietnã       Ásia  Sudeste Asiático  1191  1829  2162  3404
# 191  Saara Ocidental     África   Norte da África     0     0     0     0
# 192            Iémen       Ásia    Ásia Ocidental     1     2     1     6
# 193           Zâmbia     África   África Oriental    11    17    11     7
# 194         Zimbábue     África   África Oriental    72   114   102    44
#
#      1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  2011  2012  \
# ...

# %% [markdown]
# ANALISANDO E EXPLORANDO OS DADOS - VERIFICANDO SE POSSUI ALGUM DADO NULO PARA SER TRATADO:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 38 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   País        195 non-null    object
#  1   Continente  195 non-null    object
#  2   Região      195 non-null    object
#  3   1980        195 non-null    int64
#  4   1981        195 non-null    int64
#  5   1982        195 non-null    int64
#  6   1983        195 non-null    int64
#  7   1984        195 non-null    int64
#  8   1985        195 non-null    int64
#  9   1986        195 non-null    int64
#  10  1987        195 non-null    int64
#  11  1988        195 non-null    int64
#  12  1989        195 non-null    int64
#  13  1990        195 non-null    int64
#  14  1991        195 non-null    int64
#  15  1992        195 non-null    int64
#  16  1993        195 non-null    int64
#  17  1994        195 non-null    int64
#  18  1995        195 non-null    int64
# ...

# %% [markdown]
# ANALISAR AS TENDENCIAS DE IMIGRACAO DO BRASIL EM UM DETERMINADO PERIODO:

# %% [markdown]
# ALTERANDO O INDEX DO DATAFRAME - SETANDO A COLUNA País COMO INDEX:

# %%
df.set_index('País', inplace=True)

# %% [markdown]
# CRIANDO A VARIAVEL PARA ARMAZENAR EM UMA LISTA O INTERVALO DE TEMPO DOS ANOS:

# %%
anos = list(map(str,range(1980, 2014)))

# %%
anos
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %% [markdown]
# BUSCANDO SOMENTE OS DADOS REFERENTE AO BRASIL DENTRO DO INTERVALO DEFINIDO NA VARIAVEL "ANOS":

# %%
brasil = df.loc['Brasil', anos]

# %%
brasil
# Out:
# 1980     211
# 1981     220
# 1982     192
# 1983     139
# 1984     145
# 1985     130
# 1986     205
# 1987     244
# 1988     394
# 1989     650
# 1990     650
# 1991     877
# 1992    1066
# 1993     866
# 1994     566
# 1995     572
# 1996     586
# 1997     591
# 1998     531
# 1999     626
# 2000     845
# 2001     847
# 2002     745
# 2003     839
# 2004     917
# 2005     969
# 2006    1181
# 2007    1746
# 2008    2138
# 2009    2509
# 2010    2598
# 2011    1508
# 2012    1642
# 2013    1714
# Name: Brasil, dtype: object

# %% [markdown]
# CONVERTENDO A SERIE CRIADA EM UM DATAFRAME:

# %% [markdown]
# 1 - CRIANDO O DICIONARIO E CONVERTENDO A SERIE EM UMA LISTA:

# %%
brasil_dict = {'ano' : brasil.index.tolist(), 'imigrantes' : brasil.values.tolist()}

# %% [markdown]
# 2 - CRIANDO O DATAFRAME:

# %%
dados_brasil = pd.DataFrame(brasil_dict)
dados_brasil
# Out:
#      ano  imigrantes
# 0   1980         211
# 1   1981         220
# 2   1982         192
# 3   1983         139
# 4   1984         145
# 5   1985         130
# 6   1986         205
# 7   1987         244
# 8   1988         394
# 9   1989         650
# 10  1990         650
# 11  1991         877
# 12  1992        1066
# 13  1993         866
# 14  1994         566
# 15  1995         572
# 16  1996         586
# 17  1997         591
# 18  1998         531
# 19  1999         626
# 20  2000         845
# 21  2001         847
# 22  2002         745
# 23  2003         839
# 24  2004         917
# 25  2005         969
# 26  2006        1181
# 27  2007        1746
# 28  2008        2138
# 29  2009        2509
# 30  2010        2598
# 31  2011        1508
# 32  2012        1642
# 33  2013        1714

# %% [markdown]
# CRIANDO O GRAFICO DE LINHAS (COM MATPLOTLIB) PARA ENTENDER AS TENDENCIAS DE IMIGRACAO DO BRASIL:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# AJUSTANDO O GRAFICO, TAMANHO, INTERVALO DOS EIXOS X e Y, CRIANDO TITULO E ROTULOS - E PLOTANDO O GRAFICO:

# %%
plt.figure(figsize=(8,4)) #ajustando o Tamanho do Grafico
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes'])
plt.title('Imigraçao do Brasil para o Canada')
plt.xlabel('Ano')
plt.ylabel('Numero de Imigrantes')
plt.xticks(['1980','1985','1990','1995','2000','2005', '2010']) #ajustando o intervalo de anos do eixo X
plt.yticks([500, 1000, 1500, 2000, 2500, 3000]) #ajustando o intervalo de valores do eixo y
plt.show()

# %% [markdown]
# CRIANDO FIGURA EM PYTHON - CUSTOMIZANDO O GRAFICO DE OUTRA FORMA:

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'], lw=3, color='g')# lw definindo a expessura 3 em pixels da linha do Grafico e inserindo a cor da linha como verde
#marker='o' inserindo marcadores em circulos na linha do Grafico
ax.set_title('Imigração do Brasil para o Canadá\n1980 a 2013', fontsize=18, loc='left') #criando o Titulo a Esquerda
ax.set_xlabel('Ano', fontsize=14) #criando o rotulo do eixo x
ax.set_ylabel('Numero de Imigrantes',fontsize=14) #criando o rotulo do eixo y
ax.xaxis.set_tick_params(labelsize=12) #ajustando o tamanho dos ticks valores do eixo x
ax.yaxis.set_tick_params(labelsize=12) #ajustando o tamanho dos ticks valores do eixo y
ax.xaxis.set_major_locator(plt.MultipleLocator(5)) #criando uma frequencia de 5 e 5 anos dentro do intervalo de Anos
#plt.grid(linestyle= '--') #inserindo a Grade no fundo do Grafico
ax.spines['top'].set_visible(False) #Retirando a linha do topo da borda
ax.spines['right'].set_visible(False) #Retirando a linha da direita da borda

fig.savefig('imigracao_america_sul.png', transparent=False, dpi=300, bbox_inches='tight') #salvando a imagem do grafico em png
plt.show()

# %% [markdown]
# CRIANDO SUBPLOTS EM UMA DIREÇAO NA FIGURA PARA CONTER MAIS DE UM GRAFICO NA FIGURA:

# %%
fig, axs = plt.subplots(1,2, figsize=(15,5)) # definido uma linha e 2 subplots e o tamanho

#posiçao 0 referente a criaçao do Primeiro Grafico - GRAFICO DE LINHAS
axs[0].plot(dados_brasil['ano'], dados_brasil['imigrantes'])
axs[0].set_title('Imigração do Brasil para o Canadá\n1980 a 2013')
axs[0].set_xlabel('Ano')
axs[0].set_ylabel('Número de imigrantes')
axs[0].xaxis.set_major_locator(plt.MultipleLocator(5)) # criando uma frequencia de 5 e 5 anos dentro do intervalo de Anos
axs[0].grid() #adicionando a grade no fundo do Grafico

#posiçao 1 referente a criaçao do Segundo Grafico - BOXPLOT
axs[1].boxplot(dados_brasil['imigrantes'])
axs[1].set_title('Boxplot da Imigração do Brasil para o Canadá\n1980 a 2013')
axs[1].set_xlabel('Brasil')
axs[1].set_ylabel('Número de imigrantes')
axs[1].grid() #adicionando a grade no fundo do Grafico

plt.show()

# %%
dados_brasil.describe()
# Out:
#         imigrantes
# count    34.000000
# mean    872.323529
# std     663.401232
# min     130.000000
# 25%     428.250000
# 50%     697.500000
# 75%    1041.750000
# max    2598.000000

# %%
#O valor mínimo de imigrantes foi de 130 e o valor máximo foi de 2.598. 
#No boxplot, há pontos que são considerados outliers (valores mais altos de imigração) no período entre 2006 e 2010.
#Em 25% do período, houve 428 pessoas imigrantes; 
#Em 50% do período, houve 697 pessoas imigrante; 
#Em 75% do período, houve 1.041 pessoas imigrantes.

# %% [markdown]
# ANALISANDO AS TENDENCIAS DE IMIGRACAO PARA OS PAISES DA AMERICA DO SUL, INCLUINDO O BRASIL:

# %% [markdown]
# Criando subplots em duas direções e comparando as Tendencias em uma unica Figura - contendo 4 subplots:

# %%
fig, axs = plt.subplots(2,2, figsize=(10,6)) # definido 2 subplots em uma linha e 2 subplots na segunda linha e o tamanho
fig.subplots_adjust(hspace=0.5, wspace=0.3) #Ajustando e Melhorando o Espaçamento entre os Graficos
fig.suptitle('Imigração dos quatro maiores países da América do Sul para o Canadá de 1980 a 2013') #criando um titulo geral para os 4 Graficos

#criando o subplot do Brasil
axs[0,0].plot(df.loc['Brasil', anos])
axs[0,0].set_title('Brasil')

#criando o subplot da Colombia
axs[0,1].plot(df.loc['Colômbia', anos])
axs[0,1].set_title('Colômbia')

#criando o subplot da Argentina
axs[1,0].plot(df.loc['Argentina', anos])
axs[1,0].set_title('Argentina')

#criando o subplot do Peru
axs[1,1].plot(df.loc['Peru', anos])
axs[1,1].set_title('Peru')

#ajustando os valores do eixo x de todos os Graficos com o "for",  criando uma frequencia de 5 e 5 anos dentro do intervalo de Anos
for ax in axs.flat:
  ax.xaxis.set_major_locator(plt.MultipleLocator(5))


#ajustando os valores do eixo x e y de todos os Graficos com o "for",  criando os Rotulos
for ax in axs.flat:
  ax.set_xlabel('Ano')
  ax.set_ylabel('Número de imigrantes')

ymin = 0
ymax = 7000 #limitando os valores do eixo y de 0 a 7000 para os 4 Graficos da Figura

for ax in axs.ravel():
  ax.set_ylim(ymin, ymax)

plt.show()

# %%
#No Brasil, temos dois picos maiores: o primeiro entre 1990 e 1995, e depois um grande pico entre 2005 e 2010. 
#Na Colômbia, não há picos no começo, mas há um grande aumento a partir do final dos anos 90. Então, depois de 1995, temos um aumento bem grande, que aconteceu antes do Brasil. 
#Número de imigrantes máximo no Brasil está em 2.500, enquanto na Colômbia está em 6.000 imigrantes. Temos uma expressividade bem maior na Colômbia.
#Na Argentina, temos dois picos maiores: um entre 1990 e 1995, como no Brasil, e o segundo pico acontecendo também um pouco antes do Brasil, começando nos anos 2000. 
#No Peru, temos dois picos, um começando em 1985 e terminando no final dos anos 90, e outro começando também nos anos 2000, com um maior valor em cerca de 2010.

# %%
df.head()
# Out:
#                 Continente           Região  1980  1981  1982  1983  1984  \
# País
# Afeganistão           Ásia      Sul da Ásia    16    39    39    47    71
# Albânia             Europa    Sul da Europa     1     0     0     0     0
# Argélia             África  Norte da África    80    67    71    69    63
# Samoa Americana    Oceânia        Polinésia     0     1     0     0     0
# Andorra             Europa    Sul da Europa     0     0     0     0     0
#
#                  1985  1986  1987  ...  2005  2006  2007  2008  2009  2010  \
# País                               ...
# Afeganistão       340   496   741  ...  3436  3009  2652  2111  1746  1758
# Albânia             0     1     2  ...  1223   856   702   560   716   561
# Argélia            44    69   132  ...  3626  4807  3623  4005  5393  4752
# Samoa Americana     0     0     1  ...     0     1     0     0     0     0
# Andorra             0     2     0  ...     0     1     1     0     0     0
#
# ...

# %%
america_sul = df.query('Região == "América do Sul"') #Pesquisando e Selecionando apenas regiao da América do Sul

# %%
america_sul
# Out:
#                           Continente          Região  1980  1981  1982  1983  \
# País
# Argentina  América Latina e o Caribe  América do Sul   368   426   626   241
# Bolívia    América Latina e o Caribe  América do Sul    44    52    42    49
# Brasil     América Latina e o Caribe  América do Sul   211   220   192   139
# Chile      América Latina e o Caribe  América do Sul  1233  1069  1078   781
# Colômbia   América Latina e o Caribe  América do Sul   266   326   360   244
# Equador    América Latina e o Caribe  América do Sul   238   207   184   155
# Guiana     América Latina e o Caribe  América do Sul  2334  2943  3575  2650
# Paraguai   América Latina e o Caribe  América do Sul    45    26    32    40
# Peru       América Latina e o Caribe  América do Sul   317   456   401   241
# Suriname   América Latina e o Caribe  América do Sul    15    10    21    12
# Uruguai    América Latina e o Caribe  América do Sul   128   132   146   105
# ...

# %%
#Plotando o Grafico com Numero total de Imigracoes para cada um dos Paises - Grafico de Barras:

# %%
cores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown', 'slateblue', 'gray', 'olive', 'navy', 'teal', 'tomato'] #lista de cores criada
fig, ax = plt.subplots(figsize=(12, 5))
ax.bar(america_sul.index, america_sul['Total'], color=cores) #Colunas Index e Total
ax.set_title('Imigração da América do Sul para o Canadá\n1980 a 2013', loc='left', fontsize=18)
ax.set_xlabel('')
ax.set_ylabel('Número de imigrantes', fontsize=14)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_tick_params(labelsize=12)

plt.show()

# %% [markdown]
# CRIANDO GRAFICO DE BARRAS INVERTIDO:

# %%
cores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown', 'slateblue', 'gray', 'olive', 'navy', 'teal', 'tomato'] #lista de cores criada
fig, ax = plt.subplots(figsize=(12, 5))
ax.barh(america_sul.index, america_sul['Total'], color=cores) #Colunas Index e Total e uso da funçao "barh" para inverter o Grafico de Barras na Horizonal para uma Melhor Visualizaçao
ax.set_title('Imigração da América do Sul para o Canadá\n1980 a 2013', loc='left', fontsize=18)
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.set_ylabel('')
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_tick_params(labelsize=12)

plt.show()

# %%
#ordernando o dataframe pelo valor total do maior para o menor valor
america_sul_sorted = america_sul.sort_values('Total', ascending=True)

# %%
cores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown', 'slateblue', 'gray', 'olive', 'navy', 'teal', 'tomato'] #lista de cores criada
fig, ax = plt.subplots(figsize=(12, 5))
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color=cores) #Colunas Index e Total e uso da funçao "barh" para inverter o Grafico de Barras na Horizonal para uma Melhor Visualizaçao
ax.set_title('Imigração da América do Sul para o Canadá\n1980 a 2013', loc='left', fontsize=18)
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.set_ylabel('')
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_tick_params(labelsize=12)

plt.show()

# %%
#Guiana é o país com o maior número de imigrantes, seguido de Colômbia, Peru e o Brasil, que ficou em quarto lugar. 
#E os países com menores valores, do de maior para o de menor valor, são Uruguai, Bolívia, Paraguai e Suriname.

# %% [markdown]
# Destacando a cor da barra do Brasil em relação às outras para indficar que o Brasil é o quarto país com mais imigrantes para o Canadá no período de 1980 a 2013":

# %%
cores = []
for pais in america_sul_sorted.index:
    if pais == 'Brasil':
        cores.append('green')
    else:
        cores.append('silver')

fig, ax = plt.subplots(figsize=(12, 5))
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color=cores)
ax.set_title('América do Sul: Brasil foi o quarto país com mais imigrantes\npara o Canadá no período de 1980 a 2013', loc='left', fontsize=16)
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.set_ylabel('')
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_tick_params(labelsize=12)


#Inserindo Anotacoes no Grafico - Inserido os Valores Totais de Cada Barra / de cada Pais
for i, v in enumerate(america_sul_sorted['Total']):
    ax.text(v + 20, i, str(v), color='black', fontsize=10, ha='left', va='center')


ax.set_frame_on(False) #Retirando o Frame (a caixa que está em volta das barras)
ax.get_xaxis().set_visible(False) #Retirando o eixo X do Grafico para melhor visualizaçao uma vez que os valores totais foram inserido ao final de cada barra
ax.tick_params(axis='both', which='both', length=0) #Retirando os ticks do eixo Y

fig.savefig('imigracao_america_sul.png', transparent=False, dpi=300, bbox_inches='tight')#salvando a imagem do grafico em png

plt.show()

# %% [markdown]
# Criando o Gráfico com Seaborn:

# %%
import seaborn as sns

# %%
sns.set_theme()

# %% [markdown]
# TOP 10 DOS PAISES QUE MAIS TIVERAM IMIGRANTES PARA O CANADA:

# %%
#Criando o DATAFRAME com a ordenaçao do maior Valor para o menor Valor
top_10 = df.sort_values('Total', ascending=False).head(10) #False para ordem decrescente
top_10
# Out:
#                                       Continente            Região   1980  \
# País
# Índia                                       Ásia       Sul da Ásia   8880
# China                                       Ásia     Ásia Oriental   5123
# Reino Unido e Irlanda do Norte            Europa   Norte da Europa  22045
# Filipinas                                   Ásia  Sudeste Asiático   6051
# Paquistão                                   Ásia       Sul da Ásia    978
# Estados Unidos da América       América do Norte  América do Norte   9378
# Irã                                         Ásia       Sul da Ásia   1172
# Sri Lanka                                   Ásia       Sul da Ásia    185
# República da Coreia                         Ásia     Ásia Oriental   1011
# Polônia                                   Europa   Europa Oriental    863
#
#                                  1981   1982   1983   1984  1985  1986   1987  \
# País
# ...

# %%
#plotando Grafico de Barras no Seaborn
sns.barplot(data=top_10, x=top_10.index, y='Total') #parametro data indicando o nome do novo dataframe criado
# Out:
# <Axes: xlabel='País', ylabel='Total'>

# %% [markdown]
# CRIANDO O GRAFICO DE BARRAS NA HORIZONTAL PARA MELHORAR A VISUALIZACAO E EM VARIAS PALETAS DE CORES(SEABORN):

# %%
#parametro data indicando o nome do novo dataframe criado, invertendo os valores do eixo x e y e com parametro orient=h para horizontal. 
#parametro de cores no grafico - palette
def gerar_grafico_paleta(palette):
    fig, ax = plt.subplots(figsize=(8,4))
    ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', palette=palette)
    ax.set_title('Países com maior imigração para o Canadá\n1980 a 2013', loc='left', fontsize=18)
    ax.set_xlabel('Número de imigrantes', fontsize=14)
    ax.set_ylabel('')
    sns.despine() #removendo a linha superior e a linha à direita do gráfico
    
    plt.show()

# %%
gerar_grafico_paleta('Blues_r') #_r gerando o reverso das cores da mais escura para a mais clara 
plt.show()
# Out:
# C:\Users\RedSeek\AppData\Local\Temp\ipykernel_9656\261139490.py:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
gerar_grafico_paleta('rocket')
# Out:
# C:\Users\RedSeek\AppData\Local\Temp\ipykernel_9656\261139490.py:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
gerar_grafico_paleta('coolwarm')
# Out:
# C:\Users\RedSeek\AppData\Local\Temp\ipykernel_9656\261139490.py:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
gerar_grafico_paleta("tab10")
# Out:
# C:\Users\RedSeek\AppData\Local\Temp\ipykernel_9656\261139490.py:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
sns.set_theme(style='dark') #setando a cor do fundo do Grafico
gerar_grafico_paleta("tab10")
# Out:
# C:\Users\RedSeek\AppData\Local\Temp\ipykernel_9656\261139490.py:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
sns.set_theme(style='whitegrid')
gerar_grafico_paleta("tab10")
# Out:
# C:\Users\RedSeek\AppData\Local\Temp\ipykernel_9656\261139490.py:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
sns.set_theme(style='white')
gerar_grafico_paleta("tab10")
# Out:
# C:\Users\RedSeek\AppData\Local\Temp\ipykernel_9656\261139490.py:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
sns.set_theme(style='ticks')
gerar_grafico_paleta("tab10")
# Out:
# C:\Users\RedSeek\AppData\Local\Temp\ipykernel_9656\261139490.py:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# CRIANDO GRAFICO INTERATIVO COM O PLOTLY:

# %%
import plotly.express as px 
# No terminal executar o pip install nbformat

# %%
fig = px.line(dados_brasil, x='ano', y='imigrantes')
fig.update_traces(line_color='green', line_width=4) #alterando a cor da linha para verde e a expessura
fig.update_layout(width=1000, height=500, 
                  xaxis={'tickangle': -45}) #rotacionou os ticks dos anos em -45%
fig.show()

# %%
america_sul.head()
# Out:
#                           Continente          Região  1980  1981  1982  1983  \
# País
# Argentina  América Latina e o Caribe  América do Sul   368   426   626   241
# Bolívia    América Latina e o Caribe  América do Sul    44    52    42    49
# Brasil     América Latina e o Caribe  América do Sul   211   220   192   139
# Chile      América Latina e o Caribe  América do Sul  1233  1069  1078   781
# Colômbia   América Latina e o Caribe  América do Sul   266   326   360   244
#
#            1984  1985  1986  1987  ...  2005  2006  2007  2008  2009  2010  \
# País                               ...
# Argentina   237   196   213   519  ...  1153   847   620   540   467   459
# Bolívia      38    44    79   165  ...   134   139   107   143   214   180
# Brasil      145   130   205   244  ...   969  1181  1746  2138  2509  2598
# Chile       681   533   633  1454  ...   384   427   530   350   375   340
# Colômbia    235   214   257   376  ...  6424  6535  5357  5452  4652  5218
#
# ...

# %% [markdown]
# CRIANDO UM NOVO DATAFRAME PARA PLOTAR E VISUALIZAR MAIS DE UMA LINHA NO GRAFICO PARA CADA PAIS RESPECTIVO:

# %%
#criando um novo dataframe para plotar mais de uma linha
df_america_sul_clean = america_sul.drop(['Continente', 'Região', 'Total'], axis=1)  
#funçao drop para retirarmos colunas que não queremos visualizar. 
#axis=1 para identificar que trat-se de colunas
america_sul_final = df_america_sul_clean.T #T e a transaposiçao no DATAFRAME para que tenhamos em cada linha um Ano e em cada Coluna um Pais, transpondo os dados
america_sul_final.head()
# Out:
# País  Argentina  Bolívia  Brasil  Chile  Colômbia  Equador  Guiana  Paraguai  \
# 1980        368       44     211   1233       266      238    2334        45
# 1981        426       52     220   1069       326      207    2943        26
# 1982        626       42     192   1078       360      184    3575        32
# 1983        241       49     139    781       244      155    2650        40
# 1984        237       38     145    681       235      179    1932        48
#
# País  Peru  Suriname  Uruguai  Venezuela
# 1980   317        15      128        103
# 1981   456        10      132        117
# 1982   401        21      146        174
# 1983   241        12      105        124
# 1984   306         5       90        142

# %%
#Plotando o Grafico Interativo do novo Dataframe criado:
fig = px.line(america_sul_final, x=america_sul_final.index, y=america_sul_final.columns, color='País', 
              title='Imigração dos países da América do Sul para o Canadá de 1980 a 2013', markers=True) #marcadores inseridos
fig.update_layout(
    xaxis={'tickangle': -45},
    xaxis_title='Ano',
    yaxis_title='Número de imigrantes')

fig.show()

# %%
#Salvando o Grafico Interativo em HTML:
fig.write_html('imigracao_america_sul.html')
